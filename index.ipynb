# %% [markdown]
# Prediksi Harga rumah

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as  np 
import seaborn as sns

sns.set()

data = pd.read_csv("./Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# Data column

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# data index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=545, step=1)

# %% [markdown]
# data information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
slicing = int(2725 * 10**-1)
data = data[:slicing]
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 267   4403000  4920         3          1        2      yes        no       no
# 268   4382000  4950         4          1        2      yes        no       no
# 269   4375000  3900         3          1        2      yes        no       no
# 270   4340000  4500         3          2        3      yes        no       no
# 271   4340000  1905         5          1        2       no        no      yes
#
# ...

# %%
sns.scatterplot(data['area'])
# Out:
# <Axes: ylabel='area'>

# %%
data = data[data['area'] < 10000]

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
sns.scatterplot(data['area']) # ini cocok dijadinakn feature
plt.xlabel("Numerik")
plt.title("dataset Area")
# Out:
# Text(0.5, 1.0, 'dataset Area')

# %%
sns.histplot(data['stories']) # ini cocok dijadinakn feature
plt.xlabel("Numerik")
plt.title("dataset Area")
# Out:
# Text(0.5, 1.0, 'dataset Area')

# %%
sns.histplot(data['bathrooms']) # ini cocok dijadinakn feature
plt.xlabel("Numerik")
plt.title("dataset Area")
# Out:
# Text(0.5, 1.0, 'dataset Area')

# %%
sns.histplot(data['parking']) # ini cocok dijadinakn feature
plt.xlabel("Numerik")
plt.title("dataset Area")
# Out:
# Text(0.5, 1.0, 'dataset Area')

# %% [markdown]
# Membuat suatu model

# %% [markdown]
# Feature dan target

# %%
data = data[:500]
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 513   2485000  4400         3          1        2      yes        no       no
# 514   2485000  3000         3          1        2       no        no       no
# 515   2450000  3210         3          1        2      yes        no      yes
# 516   2450000  3240         2          1        1       no       yes       no
# 517   2450000  3000         2          1        1      yes        no       no
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

feature = np.array(data[['area', 'bedrooms','bathrooms']])
target = np.array(data['price'])

# %% [markdown]
# pembagian training set dan dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, target, test_size=0.5, random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (250, 3)
# (250, 3)
# (250,)
# (250,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# evaluasi model

# %%
y_pred = model.predict(x_test)
print(f"R2_score : {r2_score(y_test, y_pred)}")
# Out:
# R2_score : 0.408789628470447
